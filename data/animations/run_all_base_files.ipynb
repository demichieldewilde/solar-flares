# %% [markdown]
# # Run all other files
# for making videos one after the orther

# %%
import dbutils
dbutils.notebook.run("lsdfk", 60, {})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import dbutils
#       2 dbutils.notebook.run("lsdfk", 60, {})
#
# ModuleNotFoundError: No module named 'dbutils'

# %%
# %run ./lsdfk.ipynb
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Gebruiker\Anaconda3\Lib\site-packages\nbformat\reader.py:20, in parse_json(s, **kwargs)
#      19 try:
# ---> 20     nb_dict = json.loads(s, **kwargs)
#      21 except ValueError as e:
#
# File c:\Users\Gebruiker\Anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\Gebruiker\Anaconda3\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\Users\Gebruiker\Anaconda3\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# The above exception was the direct cause of the following exception:
#
# NotJSONError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 get_ipython().run_line_magic('run', './lsdfk.ipynb')
#
# File c:\Users\Gebruiker\Anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2432, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2430     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2431 with self.builtin_trap:
# -> 2432     result = fn(*args, **kwargs)
#    2434 # The code below prevents the output from being displayed
#    2435 # when using magics with decorator @output_can_be_silenced
#    2436 # when the last Python token in the expression is a ';'.
#    2437 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Gebruiker\Anaconda3\Lib\site-packages\IPython\core\magics\execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File c:\Users\Gebruiker\Anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2951, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2949 with prepended_to_syspath(dname):
#    2950     try:
# -> 2951         for cell in get_cells():
#    2952             result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2953             if raise_exceptions:
#
# File c:\Users\Gebruiker\Anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2940, in InteractiveShell.safe_execfile_ipy.<locals>.get_cells()
#    2938 if fname.suffix == ".ipynb":
#    2939     from nbformat import read
# -> 2940     nb = read(fname, as_version=4)
#    2941     if not nb.cells:
#    2942         return
#
# File c:\Users\Gebruiker\Anaconda3\Lib\site-packages\nbformat\__init__.py:169, in read(fp, as_version, capture_validation_error, **kwargs)
#     167 except AttributeError:
#     168     with open(fp, encoding="utf-8") as f:
# --> 169         return reads(f.read(), as_version, capture_validation_error, **kwargs)
#     171 return reads(buf, as_version, capture_validation_error, **kwargs)
#
# File c:\Users\Gebruiker\Anaconda3\Lib\site-packages\nbformat\__init__.py:89, in reads(s, as_version, capture_validation_error, **kwargs)
#      63 def reads(s, as_version, capture_validation_error=None, **kwargs):
#      64     """Read a notebook from a string and return the NotebookNode object as the given version.
#      65
#      66     The string can contain a notebook of any version.
#    (...)
#      87         The notebook that was read.
#      88     """
# ---> 89     nb = reader.reads(s, **kwargs)
#      90     if as_version is not NO_CONVERT:
#      91         nb = convert(nb, as_version)
#
# File c:\Users\Gebruiker\Anaconda3\Lib\site-packages\nbformat\reader.py:76, in reads(s, **kwargs)
#      51 """Read a notebook from a json string and return the
#      52 NotebookNode object.
#      53
#    (...)
#      72     Specified major version is invalid or unsupported.
#      73 """
#      74 from . import NBFormatError, versions
# ---> 76 nb_dict = parse_json(s, **kwargs)
#      77 (major, minor) = get_version(nb_dict)
#      78 if major in versions:
#
# File c:\Users\Gebruiker\Anaconda3\Lib\site-packages\nbformat\reader.py:26, in parse_json(s, **kwargs)
#      24     if len(message) > 80:  # noqa
#      25         message = message[:77] + "..."
# ---> 26     raise NotJSONError(message) from e
#      27 return nb_dict
#
# NotJSONError: Notebook does not appear to be JSON: ''

# %%
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor

filename = 'lsdfk.ipynb'
with open(filename) as ff:
    nb_in = nbformat.read(ff, nbformat.NO_CONVERT)
    
ep = ExecutePreprocessor(timeout=600, kernel_name='python3')

nb_out = ep.preprocess(nb_in)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Gebruiker\Anaconda3\Lib\site-packages\nbformat\reader.py:20, in parse_json(s, **kwargs)
#      19 try:
# ---> 20     nb_dict = json.loads(s, **kwargs)
#      21 except ValueError as e:
#
# File c:\Users\Gebruiker\Anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\Gebruiker\Anaconda3\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\Users\Gebruiker\Anaconda3\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# The above exception was the direct cause of the following exception:
#
# NotJSONError                              Traceback (most recent call last)
# Cell In[8], line 6
#       4 filename = 'lsdfk.ipynb'
#       5 with open(filename) as ff:
# ----> 6     nb_in = nbformat.read(ff, nbformat.NO_CONVERT)
#       8 ep = ExecutePreprocessor(timeout=600, kernel_name='python3')
#      10 nb_out = ep.preprocess(nb_in)
#
# File c:\Users\Gebruiker\Anaconda3\Lib\site-packages\nbformat\__init__.py:171, in read(fp, as_version, capture_validation_error, **kwargs)
#     168     with open(fp, encoding="utf-8") as f:
#     169         return reads(f.read(), as_version, capture_validation_error, **kwargs)
# --> 171 return reads(buf, as_version, capture_validation_error, **kwargs)
#
# File c:\Users\Gebruiker\Anaconda3\Lib\site-packages\nbformat\__init__.py:89, in reads(s, as_version, capture_validation_error, **kwargs)
#      63 def reads(s, as_version, capture_validation_error=None, **kwargs):
#      64     """Read a notebook from a string and return the NotebookNode object as the given version.
#      65
#      66     The string can contain a notebook of any version.
#    (...)
#      87         The notebook that was read.
#      88     """
# ---> 89     nb = reader.reads(s, **kwargs)
#      90     if as_version is not NO_CONVERT:
#      91         nb = convert(nb, as_version)
#
# File c:\Users\Gebruiker\Anaconda3\Lib\site-packages\nbformat\reader.py:76, in reads(s, **kwargs)
#      51 """Read a notebook from a json string and return the
#      52 NotebookNode object.
#      53
#    (...)
#      72     Specified major version is invalid or unsupported.
#      73 """
#      74 from . import NBFormatError, versions
# ---> 76 nb_dict = parse_json(s, **kwargs)
#      77 (major, minor) = get_version(nb_dict)
#      78 if major in versions:
#
# File c:\Users\Gebruiker\Anaconda3\Lib\site-packages\nbformat\reader.py:26, in parse_json(s, **kwargs)
#      24     if len(message) > 80:  # noqa
#      25         message = message[:77] + "..."
# ---> 26     raise NotJSONError(message) from e
#      27 return nb_dict
#
# NotJSONError: Notebook does not appear to be JSON: ''

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import ipykernel

kernel = ipykernel.connect()
client = ipykernel.client.KernelClient(kernel)
client.execute_file('hkkm.ipynb')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import ipykernel
# ----> 3 kernel = ipykernel.connect()
#       4 client = ipykernel.client.KernelClient(kernel)
#       5 client.execute_file('hkkm.ipynb')
#
# TypeError: 'module' object is not callable
